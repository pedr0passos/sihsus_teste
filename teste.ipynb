# %%
# !pip install pysus
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 61.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 KB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 KB 36.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 76.1 MB/s eta 0:00:00
# ...

# %%
from pysus.online_data.SIH import download

# %%
estado = 'ES'
ano = 2018
banco = download(state = estado, year = ano, month=1)
print('Banco de ' + str(ano) + ' de ' + str(estado) + ' baixado! ')
# Out:
# Banco de 2018 de ES baixado!

# %%
import pandas as pd
banco
# Out:
#         UF_ZI ANO_CMPT MES_CMPT ESPEC  ... TPDISEC6 TPDISEC7 TPDISEC8 TPDISEC9
# 0      320000     2018       01    03  ...        0        0        0        0
# 1      320000     2018       01    01  ...        0        0        0        0
# 2      320000     2018       01    01  ...        0        0        0        0
# 3      320000     2018       01    01  ...        0        0        0        0
# 4      320000     2018       01    01  ...        0        0        0        0
# ...       ...      ...      ...   ...  ...      ...      ...      ...      ...
# 21171  320520     2018       01    03  ...        0        0        0        0
# 21172  320520     2018       01    03  ...        0        0        0        0
# 21173  320520     2018       01    07  ...        0        0        0        0
# 21174  320520     2018       01    02  ...        0        0        0        0
# 21175  320520     2018       01    02  ...        0        0        0        0
#
# ...

# %%
banco.to_csv('sih_2018_janeiro.csv')
